# %%
import pandas as pd

# %%
import seaborn as sns

# %%
df=pd.read_csv("TWO_CENTURIES_OF_UM_RACES.csv")

# %%
df.head(10)
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
# 5           2018  06.01.2018  Selva Costera (CHI)                  50km
# 6           2018  06.01.2018  Selva Costera (CHI)                  50km
# 7           2018  06.01.2018  Selva Costera (CHI)                  50km
# 8           2018  06.01.2018  Selva Costera (CHI)                  50km
# 9           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance         Athlete club  \
# 0                         22           4:51:39 h                Tnfrc
# ...

# %%
df.shape
# Out:
# (7461195, 13)

# %%
df.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# dtype: object

# %%
##clean up data

# %%
#step 1 show 50 mi or 50k

# %%
df[df['Event distance/length']=='50km']
# Out:
#          Year of event Event dates                             Event name  \
# 0                 2018  06.01.2018                    Selva Costera (CHI)
# 1                 2018  06.01.2018                    Selva Costera (CHI)
# 2                 2018  06.01.2018                    Selva Costera (CHI)
# 3                 2018  06.01.2018                    Selva Costera (CHI)
# 4                 2018  06.01.2018                    Selva Costera (CHI)
# ...                ...         ...                                    ...
# 7461089           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461090           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461091           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461092           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461093           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
df[df['Athlete gender']=='M']
# Out:
#          Year of event Event dates                                Event name  \
# 0                 2018  06.01.2018                       Selva Costera (CHI)
# 1                 2018  06.01.2018                       Selva Costera (CHI)
# 2                 2018  06.01.2018                       Selva Costera (CHI)
# 3                 2018  06.01.2018                       Selva Costera (CHI)
# 4                 2018  06.01.2018                       Selva Costera (CHI)
# ...                ...         ...                                       ...
# 7461189           1995  00.00.1995          Les 24 heures de Fleurbaix (FRA)
# 7461190           1995  00.00.1995                 La SainteLyon 65 km (FRA)
# 7461192           1995  00.00.1995  Szombathely 24 hours running Race  (HUN)
# 7461193           1995  00.00.1995  Szombathely 24 hours running Race  (HUN)
# 7461194           1995  00.00.1995  Szombathely 24 hours running Race  (HUN)
#
# ...

# %%
#combine 50km and 50miles

# %%
df[df['Event distance/length'].isin(['50km','50mi'])]
# Out:
#          Year of event Event dates                        Event name  \
# 0                 2018  06.01.2018               Selva Costera (CHI)
# 1                 2018  06.01.2018               Selva Costera (CHI)
# 2                 2018  06.01.2018               Selva Costera (CHI)
# 3                 2018  06.01.2018               Selva Costera (CHI)
# 4                 2018  06.01.2018               Selva Costera (CHI)
# ...                ...         ...                               ...
# 7461181           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461182           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461183           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461184           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461185           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
df[(df['Event distance/length'].isin(['50km','50mi'])) & (df['Year of event']==2020)]
# Out:
#          Year of event     Event dates  \
# 2538571           2020  07.-09.02.2020
# 2538572           2020  07.-09.02.2020
# 2538573           2020  07.-09.02.2020
# 2538574           2020  07.-09.02.2020
# 2538575           2020  07.-09.02.2020
# ...                ...             ...
# 2762404           2020      03.10.2020
# 2762405           2020      03.10.2020
# 2762406           2020      03.10.2020
# 2762407           2020      03.10.2020
# 2762408           2020      03.10.2020
#
#                                       Event name Event distance/length  \
# 2538571  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538572  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538573  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538574  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538575  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# ...

# %%
df[df['Event name']=='Bison Ultra-Trail 50 (POL)']
# Out:
#          Year of event Event dates                  Event name  \
# 2762138           2020  03.10.2020  Bison Ultra-Trail 50 (POL)
# 2762139           2020  03.10.2020  Bison Ultra-Trail 50 (POL)
# 2762140           2020  03.10.2020  Bison Ultra-Trail 50 (POL)
# 2762141           2020  03.10.2020  Bison Ultra-Trail 50 (POL)
# 2762142           2020  03.10.2020  Bison Ultra-Trail 50 (POL)
# ...                ...         ...                         ...
# 3495934           2022  01.10.2022  Bison Ultra-Trail 50 (POL)
# 3495935           2022  01.10.2022  Bison Ultra-Trail 50 (POL)
# 3495936           2022  01.10.2022  Bison Ultra-Trail 50 (POL)
# 3495937           2022  01.10.2022  Bison Ultra-Trail 50 (POL)
# 3495938           2022  01.10.2022  Bison Ultra-Trail 50 (POL)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2762138                  50km                        271           3:58:33 h
# ...

# %%
df[df['Event name']=='Bison Ultra-Trail 50 (POL)']['Event name'].str.split('(').str.get(1).str.split(')').str.get(0)
# Out:
# 2762138    POL
# 2762139    POL
# 2762140    POL
# 2762141    POL
# 2762142    POL
#           ...
# 3495934    POL
# 3495935    POL
# 3495936    POL
# 3495937    POL
# 3495938    POL
# Name: Event name, Length: 794, dtype: object

# %%
df[df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0)=="USA"]
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...

# %%
#combine all the filters together
#indian events 50km or 50mi happened in 2020

# %%
df[(df['Event distance/length'].isin(['50km','50mi']))&(df['Year of event']==2020)&(df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0)=="IND")]
# Out:
#          Year of event Event dates  \
# 2565127           2020  05.01.2020
# 2565128           2020  05.01.2020
# 2565129           2020  05.01.2020
# 2565130           2020  05.01.2020
# 2565131           2020  05.01.2020
# ...                ...         ...
# 2722585           2020  12.11.2020
# 2722586           2020  12.11.2020
# 2722587           2020  12.11.2020
# 2722588           2020  12.11.2020
# 2722589           2020  12.11.2020
#
#                                                Event name  \
# 2565127  Chambal Challenge - Chambal Maharana 50 Km (IND)
# 2565128  Chambal Challenge - Chambal Maharana 50 Km (IND)
# 2565129  Chambal Challenge - Chambal Maharana 50 Km (IND)
# 2565130  Chambal Challenge - Chambal Maharana 50 Km (IND)
# 2565131  Chambal Challenge - Chambal Maharana 50 Km (IND)
# ...                                                   ...
# 2722585                    Shivalik Ultra Run 50 Km (IND)
# 2722586                    Shivalik Ultra Run 50 Km (IND)
# ...

# %%
df2=df[(df['Event distance/length'].isin(['50km','50mi']))&(df['Year of event']==2020)&(df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0)=="IND")]

# %%
df2.head(10)
# Out:
#          Year of event Event dates  \
# 2565127           2020  05.01.2020
# 2565128           2020  05.01.2020
# 2565129           2020  05.01.2020
# 2565130           2020  05.01.2020
# 2565131           2020  05.01.2020
# 2565132           2020  05.01.2020
# 2565133           2020  05.01.2020
# 2565134           2020  05.01.2020
# 2565135           2020  05.01.2020
# 2565136           2020  05.01.2020
#
#                                                Event name  \
# 2565127  Chambal Challenge - Chambal Maharana 50 Km (IND)
# 2565128  Chambal Challenge - Chambal Maharana 50 Km (IND)
# 2565129  Chambal Challenge - Chambal Maharana 50 Km (IND)
# 2565130  Chambal Challenge - Chambal Maharana 50 Km (IND)
# 2565131  Chambal Challenge - Chambal Maharana 50 Km (IND)
# 2565132  Chambal Challenge - Chambal Maharana 50 Km (IND)
# 2565133  Chambal Challenge - Chambal Maharana 50 Km (IND)
# 2565134  Chambal Challenge - Chambal Maharana 50 Km (IND)
# ...

# %%
df2.shape
# Out:
# (300, 13)

# %%
#remove (IND)from event name

# %%
df2['Event name'].str.split('(').str.get(0)
# Out:
# 2565127    Chambal Challenge - Chambal Maharana 50 Km
# 2565128    Chambal Challenge - Chambal Maharana 50 Km
# 2565129    Chambal Challenge - Chambal Maharana 50 Km
# 2565130    Chambal Challenge - Chambal Maharana 50 Km
# 2565131    Chambal Challenge - Chambal Maharana 50 Km
#                               ...
# 2722585                      Shivalik Ultra Run 50 Km
# 2722586                      Shivalik Ultra Run 50 Km
# 2722587                      Shivalik Ultra Run 50 Km
# 2722588                      Shivalik Ultra Run 50 Km
# 2722589                      Shivalik Ultra Run 50 Km
# Name: Event name, Length: 300, dtype: object

# %%
df2['Event name']=df2['Event name'].str.split('(').str.get(0)
# Out:
# C:\Users\bhujb\AppData\Local\Temp\ipykernel_14172\2517910487.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Event name']=df2['Event name'].str.split('(').str.get(0)

# %%
df2.head()
# Out:
#          Year of event Event dates  \
# 2565127           2020  05.01.2020
# 2565128           2020  05.01.2020
# 2565129           2020  05.01.2020
# 2565130           2020  05.01.2020
# 2565131           2020  05.01.2020
#
#                                           Event name Event distance/length  \
# 2565127  Chambal Challenge - Chambal Maharana 50 Km                   50km
# 2565128  Chambal Challenge - Chambal Maharana 50 Km                   50km
# 2565129  Chambal Challenge - Chambal Maharana 50 Km                   50km
# 2565130  Chambal Challenge - Chambal Maharana 50 Km                   50km
# 2565131  Chambal Challenge - Chambal Maharana 50 Km                   50km
#
#          Event number of finishers Athlete performance Athlete club  \
# 2565127                         58           4:00:13 h          NaN
# 2565128                         58           4:30:36 h          NaN
# 2565129                         58           4:31:58 h          NaN
# ...

# %%
#clean up athlete age

# %%
df2['athlete_age']=2020-df2['Athlete year of birth']
# Out:
# C:\Users\bhujb\AppData\Local\Temp\ipykernel_14172\2399030842.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['athlete_age']=2020-df2['Athlete year of birth']

# %%
#remove h from athelete performance

# %%
df2['Athlete performance']=df2['Athlete performance'].str.split(' ').str.get(0)
# Out:
# C:\Users\bhujb\AppData\Local\Temp\ipykernel_14172\2382045920.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete performance']=df2['Athlete performance'].str.split(' ').str.get(0)

# %%
df2.head()
# Out:
#          Year of event Event dates  \
# 2565127           2020  05.01.2020
# 2565128           2020  05.01.2020
# 2565129           2020  05.01.2020
# 2565130           2020  05.01.2020
# 2565131           2020  05.01.2020
#
#                                           Event name Event distance/length  \
# 2565127  Chambal Challenge - Chambal Maharana 50 Km                   50km
# 2565128  Chambal Challenge - Chambal Maharana 50 Km                   50km
# 2565129  Chambal Challenge - Chambal Maharana 50 Km                   50km
# 2565130  Chambal Challenge - Chambal Maharana 50 Km                   50km
# 2565131  Chambal Challenge - Chambal Maharana 50 Km                   50km
#
#          Event number of finishers Athlete performance Athlete club  \
# 2565127                         58             4:00:13          NaN
# 2565128                         58             4:30:36          NaN
# 2565129                         58             4:31:58          NaN
# ...

# %%
#drop columns:Athelete club ,Athlete Country,Athelete year of birth,Athelete age category

# %%
df2=df2.drop(['Athlete club','Athlete country','Athlete year of birth','Athlete age category'],axis=1)

# %%
df2.head()
# Out:
#          Year of event Event dates  \
# 2565127           2020  05.01.2020
# 2565128           2020  05.01.2020
# 2565129           2020  05.01.2020
# 2565130           2020  05.01.2020
# 2565131           2020  05.01.2020
#
#                                           Event name Event distance/length  \
# 2565127  Chambal Challenge - Chambal Maharana 50 Km                   50km
# 2565128  Chambal Challenge - Chambal Maharana 50 Km                   50km
# 2565129  Chambal Challenge - Chambal Maharana 50 Km                   50km
# 2565130  Chambal Challenge - Chambal Maharana 50 Km                   50km
# 2565131  Chambal Challenge - Chambal Maharana 50 Km                   50km
#
#          Event number of finishers Athlete performance Athlete gender  \
# 2565127                         58             4:00:13              M
# 2565128                         58             4:30:36              M
# 2565129                         58             4:31:58              M
# ...

# %%
##Clean up null values

# %%
df2.isna().sum()
# Out:
# Year of event                  0
# Event dates                    0
# Event name                     0
# Event distance/length          0
# Event number of finishers      0
# Athlete performance            0
# Athlete gender                 0
# Athlete average speed          0
# Athlete ID                     0
# athlete_age                  184
# dtype: int64

# %%
df2[df2['athlete_age'].isna()==1]
# Out:
#          Year of event Event dates  \
# 2565131           2020  05.01.2020
# 2565134           2020  05.01.2020
# 2565135           2020  05.01.2020
# 2565136           2020  05.01.2020
# 2565138           2020  05.01.2020
# ...                ...         ...
# 2722583           2020  12.11.2020
# 2722584           2020  12.11.2020
# 2722587           2020  12.11.2020
# 2722588           2020  12.11.2020
# 2722589           2020  12.11.2020
#
#                                           Event name Event distance/length  \
# 2565131  Chambal Challenge - Chambal Maharana 50 Km                   50km
# 2565134  Chambal Challenge - Chambal Maharana 50 Km                   50km
# 2565135  Chambal Challenge - Chambal Maharana 50 Km                   50km
# 2565136  Chambal Challenge - Chambal Maharana 50 Km                   50km
# 2565138  Chambal Challenge - Chambal Maharana 50 Km                   50km
# ...                                              ...                   ...
# ...

# %%
df2=df2.dropna()

# %%
df2.shape
# Out:
# (116, 10)

# %%
#Check for duplicates

# %%
df2[df2.duplicated()==True]
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete gender, Athlete average speed, Athlete ID, athlete_age]
# Index: []

# %%
#reset index

# %%
df2.reset_index(drop=True)
# Out:
#      Year of event Event dates                                   Event name  \
# 0             2020  05.01.2020  Chambal Challenge - Chambal Maharana 50 Km
# 1             2020  05.01.2020  Chambal Challenge - Chambal Maharana 50 Km
# 2             2020  05.01.2020  Chambal Challenge - Chambal Maharana 50 Km
# 3             2020  05.01.2020  Chambal Challenge - Chambal Maharana 50 Km
# 4             2020  05.01.2020  Chambal Challenge - Chambal Maharana 50 Km
# ..             ...         ...                                          ...
# 111           2020  09.02.2020                      Ruggedian Kolhapur Run
# 112           2020  09.02.2020                      Ruggedian Kolhapur Run
# 113           2020  09.02.2020                      Ruggedian Kolhapur Run
# 114           2020  12.11.2020                    Shivalik Ultra Run 50 Km
# 115           2020  12.11.2020                    Shivalik Ultra Run 50 Km
#
# ...

# %%
#fix types

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed         object
# Athlete ID                     int64
# athlete_age                  float64
# dtype: object

# %%
df2['athlete_age']=df2['athlete_age'].astype(int)

# %%
df2.dtypes
# Out:
# Year of event                 int64
# Event dates                  object
# Event name                   object
# Event distance/length        object
# Event number of finishers     int64
# Athlete performance          object
# Athlete gender               object
# Athlete average speed        object
# Athlete ID                    int64
# athlete_age                   int32
# dtype: object

# %%
df2['Athlete average speed']=df2['Athlete average speed'].astype(float)

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed        float64
# Athlete ID                     int64
# athlete_age                    int32
# dtype: object

# %%
df2.head()
# Out:
#          Year of event Event dates  \
# 2565127           2020  05.01.2020
# 2565128           2020  05.01.2020
# 2565129           2020  05.01.2020
# 2565130           2020  05.01.2020
# 2565132           2020  05.01.2020
#
#                                           Event name Event distance/length  \
# 2565127  Chambal Challenge - Chambal Maharana 50 Km                   50km
# 2565128  Chambal Challenge - Chambal Maharana 50 Km                   50km
# 2565129  Chambal Challenge - Chambal Maharana 50 Km                   50km
# 2565130  Chambal Challenge - Chambal Maharana 50 Km                   50km
# 2565132  Chambal Challenge - Chambal Maharana 50 Km                   50km
#
#          Event number of finishers Athlete performance Athlete gender  \
# 2565127                         58             4:00:13              M
# 2565128                         58             4:30:36              M
# 2565129                         58             4:31:58              M
# ...

# %%
#rename colums

# %%
"""Year of event                  int64
Event dates                   object
Event name                    object
Event distance/length         object
Event number of finishers      int64
Athlete performance           object
Athlete gender                object
Athlete average speed        float64
Athlete ID                     int64
athlete_age                    int32
dtype: object"""
# Out:
# 'Year of event                  int64\nEvent dates                   object\nEvent name                    object\nEvent distance/length         object\nEvent number of finishers      int64\nAthlete performance           object\nAthlete gender                object\nAthlete average speed        float64\nAthlete ID                     int64\nathlete_age                    int32\ndtype: object'

# %%
df2=df2.rename(columns={
    'Year of event':'Year',
    'Event dates':'Date',
    'Event name':'Name',
    'Event distance/length':'Distance',
    'Event number of finishers':'Finishers',
    'Athlete performance':'athlete_performance',
    'Athlete gender':'athlete_gender',
    'Athlete average speed':'athlete_average_speed',
    'Athlete ID':'athlete_id'
    

    
})

# %%
df2.head(10)
# Out:
#          Year        Date                                         Name  \
# 2565127  2020  05.01.2020  Chambal Challenge - Chambal Maharana 50 Km
# 2565128  2020  05.01.2020  Chambal Challenge - Chambal Maharana 50 Km
# 2565129  2020  05.01.2020  Chambal Challenge - Chambal Maharana 50 Km
# 2565130  2020  05.01.2020  Chambal Challenge - Chambal Maharana 50 Km
# 2565132  2020  05.01.2020  Chambal Challenge - Chambal Maharana 50 Km
# 2565133  2020  05.01.2020  Chambal Challenge - Chambal Maharana 50 Km
# 2565137  2020  05.01.2020  Chambal Challenge - Chambal Maharana 50 Km
# 2565139  2020  05.01.2020  Chambal Challenge - Chambal Maharana 50 Km
# 2565140  2020  05.01.2020  Chambal Challenge - Chambal Maharana 50 Km
# 2565145  2020  05.01.2020  Chambal Challenge - Chambal Maharana 50 Km
#
#         Distance  Finishers athlete_performance athlete_gender  \
# 2565127     50km         58             4:00:13              M
# 2565128     50km         58             4:30:36              M
# ...

# %%
#find athlete id 68329

# %%
df2[df2['athlete_id']==68329]
# Out:
#          Year        Date                                         Name  \
# 2565127  2020  05.01.2020  Chambal Challenge - Chambal Maharana 50 Km
#
#         Distance  Finishers athlete_performance athlete_gender  \
# 2565127     50km         58             4:00:13              M
#
#          athlete_average_speed  athlete_id  athlete_age
# 2565127                 12.489       68329           31

# %%
df2.head(1)
# Out:
#          Year        Date                                         Name  \
# 2565127  2020  05.01.2020  Chambal Challenge - Chambal Maharana 50 Km
#
#         Distance  Finishers athlete_performance athlete_gender  \
# 2565127     50km         58             4:00:13              M
#
#          athlete_average_speed  athlete_id  athlete_age
# 2565127                 12.489       68329           31

# %%
sns.histplot(df2['Distance'])
# Out:
# <Axes: xlabel='Distance', ylabel='Count'>

# %%
sns.histplot(df2,x='Distance',hue='athlete_gender')
# Out:
# <Axes: xlabel='Distance', ylabel='Count'>

# %%
sns.displot(df2[df2['Distance']=='50km']['athlete_average_speed'])

# %%
sns.violinplot(data=df2,x='Distance',y='athlete_average_speed',hue='athlete_gender',split=True,inner='quart',linewidth=1)
# Out:
# <Axes: xlabel='Distance', ylabel='athlete_average_speed'>

# %%
sns.lmplot(data=df2,x='athlete_age',y='athlete_average_speed',hue='athlete_gender')

# %%
#question i want to find out from the data

# %%
#differnece in the speed for the 50k and 50mi male to female

# %%
df2.groupby(['Distance','athlete_gender'])['athlete_average_speed'].mean()
# Out:
# Distance  athlete_gender
# 50km      F                 9.048765
#           M                 9.032374
# Name: athlete_average_speed, dtype: float64

# %%
#what age groups are the best in the 50km race (2+races min)

# %%
df2.query('Distance=="50km"').groupby('athlete_age')['athlete_average_speed'].agg(['mean','count']).sort_values('mean',ascending=False).query('count>2')
# Out:
#                   mean  count
# athlete_age
# 41           12.275000      4
# 31            9.977667      6
# 27            9.895750      8
# 45            9.800000      5
# 36            9.685400      5
# 30            9.681600      5
# 44            9.339250      4
# 33            9.018800      5
# 56            8.648000      3
# 25            8.636333      3
# 46            8.278400      5
# 48            8.176333      3
# 52            8.170333      3
# 35            8.165833      6
# 51            8.096667      3
# 47            8.068250      4
# 28            7.813333      3
# 37            7.617333      6
# 42            7.598750      4
# 38            7.509750      4

# %%
#what age group are the worst in the 50km race

# %%
df2.query('Distance=="50km"').groupby('athlete_age')['athlete_average_speed'].agg(['mean','count']).sort_values('mean',ascending=True).query('count>2')
# Out:
#                   mean  count
# athlete_age
# 38            7.509750      4
# 42            7.598750      4
# 37            7.617333      6
# 28            7.813333      3
# 47            8.068250      4
# 51            8.096667      3
# 35            8.165833      6
# 52            8.170333      3
# 48            8.176333      3
# 46            8.278400      5
# 25            8.636333      3
# 56            8.648000      3
# 33            9.018800      5
# 44            9.339250      4
# 30            9.681600      5
# 36            9.685400      5
# 45            9.800000      5
# 27            9.895750      8
# 31            9.977667      6
# 41           12.275000      4

# %%
df2.head(0)
# Out:
# Empty DataFrame
# Columns: [Year, Date, Name, Distance, Finishers, athlete_performance, athlete_gender, athlete_average_speed, athlete_id, athlete_age]
# Index: []

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete club, Athlete country, Athlete year of birth, Athlete gender, Athlete age category, Athlete average speed, Athlete ID]
# Index: []

# %%
df2['race_month']=df2['Date'].str.split('.').str.get(1).astype(int)

# %%
df2.head(1)
# Out:
#          Year        Date                                         Name  \
# 2565127  2020  05.01.2020  Chambal Challenge - Chambal Maharana 50 Km
#
#         Distance  Finishers athlete_performance athlete_gender  \
# 2565127     50km         58             4:00:13              M
#
#          athlete_average_speed  athlete_id  athlete_age  race_month
# 2565127                 12.489       68329           31           1

# %%
df2['race_season']=df2['race_month'].apply(lambda x:'Winter'if x>11 else 'Fall' if x>8 else 'Summer' if x>5 else 'Spring' if x>2 else 'Winter' )

# %%
df2.head(25)
# Out:
#          Year        Date                                         Name  \
# 2565127  2020  05.01.2020  Chambal Challenge - Chambal Maharana 50 Km
# 2565128  2020  05.01.2020  Chambal Challenge - Chambal Maharana 50 Km
# 2565129  2020  05.01.2020  Chambal Challenge - Chambal Maharana 50 Km
# 2565130  2020  05.01.2020  Chambal Challenge - Chambal Maharana 50 Km
# 2565132  2020  05.01.2020  Chambal Challenge - Chambal Maharana 50 Km
# 2565133  2020  05.01.2020  Chambal Challenge - Chambal Maharana 50 Km
# 2565137  2020  05.01.2020  Chambal Challenge - Chambal Maharana 50 Km
# 2565139  2020  05.01.2020  Chambal Challenge - Chambal Maharana 50 Km
# 2565140  2020  05.01.2020  Chambal Challenge - Chambal Maharana 50 Km
# 2565145  2020  05.01.2020  Chambal Challenge - Chambal Maharana 50 Km
# 2565148  2020  05.01.2020  Chambal Challenge - Chambal Maharana 50 Km
# 2565149  2020  05.01.2020  Chambal Challenge - Chambal Maharana 50 Km
# ...

# %%
df2.groupby('race_season')['athlete_average_speed'].agg(['mean','count']).sort_values('mean',ascending=False)
# Out:
#                  mean  count
# race_season
# Winter       9.064728    114
# Fall         7.327500      2
